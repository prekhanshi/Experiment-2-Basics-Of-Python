# %% [markdown]
# <a href="https://colab.research.google.com/github/prekhanshi/Experiment-2-Basics-Of-Python/blob/main/practical_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Name: Prekhanshi kumbhhakar
# # branch: ENTC
# # batch: A1
# # EXPERIMENT NO. 2
# # TITLE: BASICS OF PYTHON

# %%
#first Python Program / string
print("Hello, Welcome to Python Programming")
# Out:
# Hello, Welcome to Python Programming

# %%
#  Many Statements
print("Hello World!"); print("what is up"); print("how is life?")
# Out:
# Hello World!
# what is up
# how is life?

# %%
print("Hello World!", end= " ")
print("what is up")
# Out:
# Hello World! what is up

# %%
#print numbers
a= 2
print(a)
print(32)
# Out:
# 2
# 32

# %%
#variables
x= 5
x= "Hello World"
print (x)
# Out:
# Hello World

# %%
#variables
x= 5
y= "Hello World"
print (x)
print (y)
# Out:
# 5
# Hello World

# %%
#case sensitive
a= 4
A= "PREK"
print(a)
print(A)
# Out:
# 4
# PREK

# %%
# Many values to multiple variables
x,y,z = "orange", "banana", "cherry"
print(x)
print(y)
print(z)
# Out:
# orange
# banana
# cherry

# %%
a=2
b=8
print("addition= =", a+b)
print("subtraction=",a-b)
print("division=",a/b)
print("multiplication=",a*b)
# Out:
# addition= = 10
# subtraction= -6
# division= 0.25
# multiplication= 16

# %%
# understanding data types
x= 10
y= 3.14
z="python"
flag = True
C= 2+4j

print(type(x))
print(type(y))
print(type(z))
print(type(flag))
print(type(C))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>
# <class 'complex'>

# %%
# input from user
name= input("Enter your name: ")
print("Hello", name)
# Out:
# Enter your name: prek
# Hello prek

# %%
#simple calculator
a = int(input("Enter first number:"))
b = int(input("Enter the second number:"))
func = input("Enter the function to perform: ")
if func=="add":
 print(a+b)
if func=="subtract":
  print(a-b)
# Out:
# Enter first number:2
# Enter the second number:5
# Enter the function to perform: add
# 7

# %%
# total and avg marks
Sub1= int(input("Enter marks of subject 1:"))
Sub2= int(input("Enter marks of subject 2:"))
Sub3= int(input("Enter marks of subject 3:"))
Sub4= int(input("Enter marks of subject 4:"))
Sub5= int(input("Enter marks of subject 5:"))
Total= Sub1+Sub2+Sub3+Sub4+Sub5
print("Total marks =", Total)
Avg= Total/5
print("Average marks =", Avg)
# Out:
# Enter marks of subject 1:24
# Enter marks of subject 2:24
# Enter marks of subject 3:35
# Enter marks of subject 4:55
# Enter marks of subject 5:60
# Total marks = 198
# Average marks = 39.6

# %%
#area of rectangle
a= int(input("enter the length:"))
b= int(input('enter the breadth:'))
area= a*b
print("area of rectangle =", area2)
# Out:
# enter the length22
# enter the breadth3
# area of rectangle = 66

# %%
#area od circle
a=int(input("enter the radius:"))
area= 3.14*a*a
print("area of circle:" , area)
# Out:
# enter the radius:4
# area of circle: 50.24

# %%
#power
print(2**5)
# Out:
# 32

# %%
A = (2,3,4)+(6,7,8)
print (A)
# Out:
# (2, 3, 4, 6, 7, 8)
